# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/My Drive/Assignment/Skin cancer/Train")
data_dir_test = pathlib.Path('/content/gdrive/My Drive/Assignment/Skin cancer/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2244
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2244 files belonging to 9 classes.
# Using 1796 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2244 files belonging to 9 classes.
# Using 448 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))



model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  batch_size=batch_size,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 57/57 [==============================] - 29s 133ms/step - loss: 2.0851 - accuracy: 0.1815 - val_loss: 2.0608 - val_accuracy: 0.2009
# Epoch 2/20
# 57/57 [==============================] - 4s 76ms/step - loss: 2.0458 - accuracy: 0.2027 - val_loss: 2.0915 - val_accuracy: 0.1830
# Epoch 3/20
# 57/57 [==============================] - 4s 77ms/step - loss: 2.0389 - accuracy: 0.1915 - val_loss: 2.0312 - val_accuracy: 0.2076
# Epoch 4/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9907 - accuracy: 0.2166 - val_loss: 1.9877 - val_accuracy: 0.2321
# Epoch 5/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.9703 - accuracy: 0.2266 - val_loss: 1.9999 - val_accuracy: 0.2366
# Epoch 6/20
# 57/57 [==============================] - 4s 77ms/step - loss: 1.9588 - accuracy: 0.2389 - val_loss: 1.9484 - val_accuracy: 0.2545
# Epoch 7/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9493 - accuracy: 0.2478 - val_loss: 1.9465 - val_accuracy: 0.2143
# Epoch 8/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9488 - accuracy: 0.2411 - val_loss: 1.9737 - val_accuracy: 0.2455
# Epoch 9/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9415 - accuracy: 0.2361 - val_loss: 1.9460 - val_accuracy: 0.2500
# Epoch 10/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9311 - accuracy: 0.2545 - val_loss: 1.9507 - val_accuracy: 0.2545
# Epoch 11/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9534 - accuracy: 0.2517 - val_loss: 1.9770 - val_accuracy: 0.2210
# Epoch 12/20
# 57/57 [==============================] - 4s 75ms/step - loss: 1.9772 - accuracy: 0.2422 - val_loss: 2.0090 - val_accuracy: 0.2210
# Epoch 13/20
# 57/57 [==============================] - 4s 75ms/step - loss: 2.0473 - accuracy: 0.2339 - val_loss: 2.0047 - val_accuracy: 0.2098
# Epoch 14/20
# 57/57 [==============================] - 4s 75ms/step - loss: 1.9628 - accuracy: 0.2255 - val_loss: 1.9831 - val_accuracy: 0.2433
# Epoch 15/20
# 57/57 [==============================] - 5s 79ms/step - loss: 1.9509 - accuracy: 0.2550 - val_loss: 1.9907 - val_accuracy: 0.2589
# Epoch 16/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9497 - accuracy: 0.2355 - val_loss: 1.9932 - val_accuracy: 0.2344
# Epoch 17/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9461 - accuracy: 0.2411 - val_loss: 2.0058 - val_accuracy: 0.2254
# Epoch 18/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9396 - accuracy: 0.2439 - val_loss: 1.9814 - val_accuracy: 0.2500
# Epoch 19/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9324 - accuracy: 0.2584 - val_loss: 1.9637 - val_accuracy: 0.2500
# Epoch 20/20
# 57/57 [==============================] - 4s 76ms/step - loss: 1.9308 - accuracy: 0.2556 - val_loss: 1.9908 - val_accuracy: 0.2545

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit
#
#
# > Indented block

# %% [markdown]
# ### Write your findings here
#
# ## The model above is slightly overfitting as training accuracy is slightly higher than val accuracy
# ## The accuracy is somewhere around 25% so it's too early to conclude if the model is overfitting or underfitting

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 57/57 [==============================] - 7s 92ms/step - loss: 2.0680 - accuracy: 0.1765 - val_loss: 2.0719 - val_accuracy: 0.2009
# Epoch 2/20
# 57/57 [==============================] - 5s 87ms/step - loss: 2.0502 - accuracy: 0.1882 - val_loss: 2.0172 - val_accuracy: 0.2388
# Epoch 3/20
# 57/57 [==============================] - 5s 86ms/step - loss: 2.0285 - accuracy: 0.2021 - val_loss: 2.0295 - val_accuracy: 0.2009
# Epoch 4/20
# 57/57 [==============================] - 5s 85ms/step - loss: 2.0284 - accuracy: 0.1999 - val_loss: 2.0170 - val_accuracy: 0.1920
# Epoch 5/20
# 57/57 [==============================] - 5s 85ms/step - loss: 2.0120 - accuracy: 0.2244 - val_loss: 1.9916 - val_accuracy: 0.2054
# Epoch 6/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.9481 - accuracy: 0.2517 - val_loss: 1.9233 - val_accuracy: 0.2902
# Epoch 7/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.9097 - accuracy: 0.2901 - val_loss: 1.8558 - val_accuracy: 0.2879
# Epoch 8/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.9028 - accuracy: 0.2801 - val_loss: 1.8175 - val_accuracy: 0.3013
# Epoch 9/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.7923 - accuracy: 0.3268 - val_loss: 2.0814 - val_accuracy: 0.2321
# Epoch 10/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.7408 - accuracy: 0.3586 - val_loss: 1.6381 - val_accuracy: 0.4129
# Epoch 11/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.6828 - accuracy: 0.3736 - val_loss: 1.6298 - val_accuracy: 0.3817
# Epoch 12/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.6256 - accuracy: 0.4003 - val_loss: 1.5913 - val_accuracy: 0.4062
# Epoch 13/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.5814 - accuracy: 0.4176 - val_loss: 1.6065 - val_accuracy: 0.4062
# Epoch 14/20
# 57/57 [==============================] - 5s 84ms/step - loss: 1.6507 - accuracy: 0.3937 - val_loss: 1.5540 - val_accuracy: 0.4286
# Epoch 15/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.6658 - accuracy: 0.4009 - val_loss: 1.6016 - val_accuracy: 0.4107
# Epoch 16/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.5869 - accuracy: 0.4287 - val_loss: 1.5391 - val_accuracy: 0.4688
# Epoch 17/20
# 57/57 [==============================] - 5s 84ms/step - loss: 1.5179 - accuracy: 0.4410 - val_loss: 1.4764 - val_accuracy: 0.4643
# Epoch 18/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.5059 - accuracy: 0.4621 - val_loss: 1.6082 - val_accuracy: 0.3862
# Epoch 19/20
# 57/57 [==============================] - 5s 84ms/step - loss: 1.4538 - accuracy: 0.4621 - val_loss: 1.4499 - val_accuracy: 0.4531
# Epoch 20/20
# 57/57 [==============================] - 5s 85ms/step - loss: 1.4697 - accuracy: 0.4560 - val_loss: 1.5302 - val_accuracy: 0.4286

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# ## The accuracy has increased to 45%
# ## the problem of overfitting has somewhat been solved but it's too soon to make conclusions
# ## increasing the number of epochs might help in increasing accuracy

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# ### - Which class has the least number of samples?
# #### ANS - seborrheic keratosis
# ### - Which classes dominate the data in terms proportionate number of samples?
# #### ANS- actinic keratosis and dermatofibroma have proportionate classes as well as Melanoma and pgment benign keratosis

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/My Drive/Assignment/Skin cancer/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8622059BD0>: 100%|██████████| 500/500 [00:19<00:00, 25.07 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F86220B3350>: 100%|██████████| 500/500 [00:21<00:00, 22.90 Samples/s]
# Initialised with 100 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F862050EA90>: 100%|██████████| 500/500 [00:23<00:00, 21.16 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F86220BAA50>: 100%|██████████| 500/500 [01:34<00:00,  5.32 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=962x676 at 0x7F8622078450>: 100%|██████████| 500/500 [01:25<00:00,  5.87 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8620424A50>: 100%|██████████| 500/500 [00:18<00:00, 27.53 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F86220BE090>: 100%|██████████| 500/500 [00:41<00:00, 12.04 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F86220B3F90>: 100%|██████████| 500/500 [00:19<00:00, 26.29 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Assignment/Skin cancer/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F862042DF10>: 100%|██████████| 500/500 [00:18<00:00, 27.33 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026149.jpg_53ebf4ec-0664-44d0-acf0-b5075bc5f99d.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030877.jpg_be3a40d4-5c28-4bf3-b23e-506127f79fdc.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032206.jpg_3f1b4620-1bbf-44b0-894d-46179314308d.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028314.jpg_f0facf77-4e93-4d38-a71e-11d93d32bc9c.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029659.jpg_17ccadda-93f8-4077-8756-bd8ce075fd83.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027334.jpg_36998f59-457a-4ed2-9604-0cef6c462512.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031609.jpg_25ed9f68-f1b8-45a2-80ba-57c8de863db3.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028517.jpg_ebe23e31-5723-485d-8841-61b258bc6a4d.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026729.jpg_f2631b31-1e80-406b-8ad7-2cc4beef6a7e.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026857.jpg_b6f1abf3-190c-4c65-ba67-20762c654202.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029900.jpg_3806914f-18f8-4e1d-be6d-6e89e098a6df.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029930.jpg_a2e2527b-ae34-42f4-830d-c206f9cddbc3.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032135.jpg_40d0f461-dcba-4f09-a8a5-65655f095012.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/actinic keratosis/output/actinic keratosis_original_ISIC_
Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0024850.jpg_b4322b1a-f609-401a-86ac-42a7374a5210.jpg',
#  '/content/gdrive/My Drive/Assignment/Skin cancer/Train/pigmented benign keratosis/output/pigmented benign keratosis_original_ISIC_0028451.jpg_c63b2103-4c79-4c33-a8a1-bf52347e3925.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# actinic keratosis             500
# pigmented benign keratosis    500
# squamous cell carcinoma       500
# melanoma                      500
# seborrheic keratosis          500
# basal cell carcinoma          500
# dermatofibroma                500
# nevus                         500
# vascular lesion               500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train1=pathlib.Path("/content/gdrive/My Drive/Assignment/Skin cancer/Train")
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6744 files belonging to 9 classes.
# Using 5396 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6744 files belonging to 9 classes.
# Using 1348 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D , BatchNormalization
num_classes = 9
model = Sequential([ 
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())


model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 169/169 [==============================] - 50s 283ms/step - loss: 2.5463 - accuracy: 0.3812 - val_loss: 2.6588 - val_accuracy: 0.2285
# Epoch 2/30
# 169/169 [==============================] - 33s 190ms/step - loss: 1.6152 - accuracy: 0.5083 - val_loss: 2.5277 - val_accuracy: 0.2886
# Epoch 3/30
# 169/169 [==============================] - 34s 196ms/step - loss: 1.2684 - accuracy: 0.5847 - val_loss: 1.5316 - val_accuracy: 0.5430
# Epoch 4/30
# 169/169 [==============================] - 33s 188ms/step - loss: 1.0379 - accuracy: 0.6640 - val_loss: 1.5323 - val_accuracy: 0.5349
# Epoch 5/30
# 169/169 [==============================] - 33s 187ms/step - loss: 0.8042 - accuracy: 0.7263 - val_loss: 1.3772 - val_accuracy: 0.6009
# Epoch 6/30
# 169/169 [==============================] - 33s 188ms/step - loss: 0.7481 - accuracy: 0.7363 - val_loss: 5.0719 - val_accuracy: 0.2619
# Epoch 7/30
# 169/169 [==============================] - 33s 188ms/step - loss: 0.6641 - accuracy: 0.7652 - val_loss: 1.1640 - val_accuracy: 0.6276
# Epoch 8/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.5609 - accuracy: 0.8089 - val_loss: 1.2144 - val_accuracy: 0.6461
# Epoch 9/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.5116 - accuracy: 0.8254 - val_loss: 1.1908 - val_accuracy: 0.6728
# Epoch 10/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.4348 - accuracy: 0.8514 - val_loss: 1.1347 - val_accuracy: 0.7025
# Epoch 11/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.4087 - accuracy: 0.8649 - val_loss: 0.9876 - val_accuracy: 0.7077
# Epoch 12/30
# 169/169 [==============================] - 33s 187ms/step - loss: 0.3777 - accuracy: 0.8684 - val_loss: 1.0434 - val_accuracy: 0.7166
# Epoch 13/30
# 169/169 [==============================] - 33s 188ms/step - loss: 0.3834 - accuracy: 0.8732 - val_loss: 3.5076 - val_accuracy: 0.4177
# Epoch 14/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.3636 - accuracy: 0.8808 - val_loss: 1.0334 - val_accuracy: 0.7122
# Epoch 15/30
# 169/169 [==============================] - 33s 190ms/step - loss: 0.3437 - accuracy: 0.8903 - val_loss: 1.0945 - val_accuracy: 0.6966
# Epoch 16/30
# 169/169 [==============================] - 33s 188ms/step - loss: 0.3029 - accuracy: 0.8981 - val_loss: 0.9679 - val_accuracy: 0.7255
# Epoch 17/30
# 169/169 [==============================] - 33s 190ms/step - loss: 0.3207 - accuracy: 0.8907 - val_loss: 1.0623 - val_accuracy: 0.7344
# Epoch 18/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.2979 - accuracy: 0.9033 - val_loss: 0.9404 - val_accuracy: 0.7789
# Epoch 19/30
# 169/169 [==============================] - 34s 192ms/step - loss: 0.2973 - accuracy: 0.9031 - val_loss: 1.1444 - val_accuracy: 0.7033
# Epoch 20/30
# 169/169 [==============================] - 34s 193ms/step - loss: 0.2689 - accuracy: 0.9135 - val_loss: 2.0716 - val_accuracy: 0.5252
# Epoch 21/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.2909 - accuracy: 0.9044 - val_loss: 3.8960 - val_accuracy: 0.4221
# Epoch 22/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.3121 - accuracy: 0.8997 - val_loss: 3.3369 - val_accuracy: 0.4933
# Epoch 23/30
# 169/169 [==============================] - 33s 190ms/step - loss: 0.2632 - accuracy: 0.9179 - val_loss: 2.5949 - val_accuracy: 0.5126
# Epoch 24/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.2607 - accuracy: 0.9135 - val_loss: 1.3397 - val_accuracy: 0.7151
# Epoch 25/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.2509 - accuracy: 0.9196 - val_loss: 1.8427 - val_accuracy: 0.5942
# Epoch 26/30
# 169/169 [==============================] - 33s 189ms/step - loss: 0.2316 - accuracy: 0.9255 - val_loss: 0.9736 - val_accuracy: 0.7789
# Epoch 27/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.2489 - accuracy: 0.9192 - val_loss: 1.4418 - val_accuracy: 0.6818
# Epoch 28/30
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2319 - accuracy: 0.9207 - val_loss: 2.5344 - val_accuracy: 0.6409
# Epoch 29/30
# 169/169 [==============================] - 33s 187ms/step - loss: 0.2411 - accuracy: 0.9264 - val_loss: 2.3922 - val_accuracy: 0.6068
# Epoch 30/30
# 169/169 [==============================] - 33s 188ms/step - loss: 0.2387 - accuracy: 0.9257 - val_loss: 1.5811 - val_accuracy: 0.6899

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ## -Accuracy on training has increased significantly when augmented
# ## -Model seems to be overfitting
# ## -Recommendation to add more layers , neurons and dropout may solve the case of overfitting
# ## -hyperparameters tuning can be utlized as well
